# %%
# %load_ext Cython

# %%
# %%cython --a
#
#
#
# #-*- coding: utf-8 -*-
#
# import csv
# import math
# import ccxt
# import time
# import datetime
# import numpy as np
#
#
# def bb(x, int w, float k): # 볼린저 밴드
#     mbb = HMA(x, w)
#     lbb = mbb - k * np.std(x[-w:])
#     ubb = mbb + k * np.std(x[-w:])
#     return lbb[-1], ubb[-1]
#
# def WMA(df, int period): # 가중이동평균
#     cdef float value = 0.0
#     cdef int epoch = 0
#     cdef int n = 0
#     result = []
#
#     cdef int EndPoint = len(df) - period + 1
#     for epoch in range(EndPoint):
#         value = 0
#         for n in range(1, period+1):
#             value = value + ((df[n+epoch-1]) * n)
#         result.append(value / ((period * (period + 1)) / 2))
#     return result
#
# def HMA(df, int period): # Hull 이동평균
#     cdef int i = 0
#     data1 = WMA(df, int(period/2))
#     cdef int EndPoint_1 = len(data1)
#     for i in range(0, EndPoint_1):
#         data1[i] = data1[i] * 2
#     data2 = WMA(df, period)
#     data3 = []
#     cdef int EndPoint_2 = len(data2)
#     i = 0
#     for i in range(0, EndPoint_2):
#         data3.append(data1[i + EndPoint_1 - EndPoint_2] - data2[i])
#     return (WMA(data3, int(math.sqrt(period))))
#
#
#
#
# def log_maker(int length_, float std_):
#     cdef int j = 0
#     cdef int i = 0
#     cdef int idx = 0
#     cdef EndPoint_1 = len(All_ohlcv)
#     cdef float close_ = 0.0
#     cdef float lbb_ = 0.0
#     cdef float ubb_ = 0.0
#     cdef float buy_price = 0.0
#     cdef float earning = 0.0
#
#     for j in range(EndPoint_1):
#         price.clear()
#         ohlcv = All_ohlcv[j]
#         i = length_ + 6
#         first_trade_buy = None
#         is_buy_entering = None
#         while(i < len(ohlcv)- 2):
#             close_ = ohlcv[i]
#             lbb_, ubb_= bb(ohlcv[i-5-length_:i], length_, std_)
#             i += 1
#             if close_ > ubb_ and is_buy_entering != False:
#                 buy_price = ohlcv[i+1]
#                 price.append(buy_price)
#                 is_buy_entering =False
#                 if first_trade_buy == None:
#                     first_trade_buy = False
#             elif close_ < lbb_ and is_buy_entering != True:
#                 buy_price = ohlcv[i+1]
#                 price.append(buy_price)
#                 is_buy_entering = True
#                 if first_trade_buy == None:
#                     first_trade_buy = True
#         for idx in range(len(price)-1):
#             if (first_trade_buy == True and idx % 2 == 0) or (first_trade_buy == False and idx % 2 == 1):
#                 # normal
#                 earning = 100 * ((price[idx+1] / price[idx]) * 0.99925 * 0.99925 - 1)
#                 buy_sell_log.append(earning)
#             else:
#                 # reverse
#                 earning = 100 * ((price[idx] / price[idx+1]) * 0.99925 * 0.99925 - 1)
#                 buy_sell_log.append(earning)
#
#
#
# def get_perfomance(trade_log):
#     import numpy
#     win = []
#     lose = []
#     cdef int i = 0
#     cdef float win_Rate = 0.0
#     for i in range(len(trade_log)):
#         if trade_log[i] > 0:
#             win.append(trade_log[i])
#         elif trade_log[i] < 0:
#             lose.append(trade_log[i])
#     win_Rate = round(100 * len(win) / len(trade_log), 2)
#
#
#     return [win_Rate, -1 * numpy.mean(win) / numpy.mean(lose)]
#
#
# def csv2list(filename):
#     file = open(filename, 'r')
#     csvfile = csv.reader(file)
#     lists = []
#     for item in csvfile:
#         lists.append(item)
#     return lists
#
#
#
# cdef int i
# cdef int j
#
#
# csv_ = csv2list('result.csv')
# price = []
# buy_sell_log = []
#
# All_ohlcv = []
#
# for i in range(len(csv_)):
#     temp = [float(x) for x in csv_[i]]
#     All_ohlcv.append(temp)
#
#
# '''
# log_maker(30, 2.5)
# get_perfomance(buy_sell_log)
# price.clear()
# buy_sell_log.clear()
#
#
# # a = [MA_value, STD_value, win_rate, avg_P&L, win_rate * (1 + avg_P&L) ]
#
# '''
# csv_list = []
#
# for i in range(2,40,2):
#     for j in range(1, 30):
#         log_maker(i, round(j*0.1, 2))
#         aa = get_perfomance(buy_sell_log)
#
#         print('MA 파라미터 :', i)
#         print('STD 파라미터 :', j)
#         print('평균손익비 :', aa[1])
#         print('승률 :', aa[0])
#         print('')
#
#
#         csv_list.append([i,j,aa[0],aa[1]])
#         price.clear()
#         buy_sell_log.clear()
#
# print(csv_list)
#
# f = open('output.csv','w',encoding="euc-kr",newline='')
#
# wr = csv.writer(f)
#
# try:
#     i = 0
#     while(len(csv_list)):
#         if i ==0:
#             wr.writerow(["MA", "STD", "WinRate", "AVG_PNL", "factor"])
#         wr.writerow([csv_list[i], csv_list[i+1], csv_list[i+2], csv_list[i+3], csv_list[i+4]])
#         i = i+5
# except:
#     print("프로그램 실행 완료")
# f.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-da2aca0efe3b> in <module>
# ----> 1 get_ipython().run_cell_magic('cython', '--a', '\n\n\n#-*- coding: utf-8 -*- \n\nimport csv\nimport math\nimport ccxt\nimport time\nimport datetime\nimport numpy as np\n\n\ndef bb(x, int w, float k): # 볼린저 밴드\n    mbb = HMA(x, w)\n    lbb = mbb - k * np.std(x[-w:])\n    ubb = mbb + k * np.std(x[-w:])\n    return lbb[-1], ubb[-1]\n\ndef WMA(df, int period): # 가중이동평균\n    cdef float value = 0.0\n    cdef int epoch = 0\n    cdef int n = 0\n    result = []\n    \n    cdef int EndPoint = len(df) - period + 1\n    for epoch in range(EndPoint):\n        value = 0\n        for n in range(1, period+1):\n            value = value + ((df[n+epoch-1]) * n)\n        result.append(value / ((period * (period + 1)) / 2))\n    return result\n\ndef HMA(df, int period): # Hull 이동평균\n    cdef int i = 0\n    data1 = WMA(df, int(period/2))\n    cdef int EndPoint_1 = len(data1)\n    for i in range(0, EndPoint_1):\n        data1[i] = data1[i] * 2\n    data2 = WMA(df, period)\n    data3 = []\n    cdef int EndPoint_2 = len(data2)\n    i = 0\n    for i in range(0, EndPoint_2):\n        data3.append(data1[i + EndPoint_1 - EndPoint_2] - data2[i])\n    return (WMA(data3, int(math.sqrt(period))))\n\n\n\n\ndef log_maker(int length_, float std_):\n    cdef int j = 0\n    cdef int i = 0\n    cdef int idx = 0\n    cdef EndPoint_1 = len(All_ohlcv)\n    cdef float close_ = 0.0\n    cdef float lbb_ = 0.0\n    cdef float ubb_ = 0.0\n    cdef float buy_price = 0.0\n    cdef float earning = 0.0\n    \n    for j in range(EndPoint_1):\n        price.clear()\n        ohlcv = All_ohlcv[j]\n        i = length_ + 6\n        first_trade_buy = None\n        is_buy_entering = None\n        while(i < len(ohlcv)- 2):\n            close_ = ohlcv[i]\n            lbb_, ubb_= bb(ohlcv[i-5-length_:i], length_, std_)\n            i += 1\n            if close_ > ubb_ and is_buy_entering != False:\n                buy_price = ohlcv[i+1]\n                price.append(buy_price)\n                is_buy_entering =False\n                if first_trade_buy == None:\n                    first_trade_buy = False \n            elif close_ < lbb_ and is_buy_entering != True:\n                buy_price = ohlcv[i+1]\n                price.append(buy_price)\n                is_buy_entering = True\n                if first_trade_buy == None:\n                    first_trade_buy = True\n        for idx in range(len(price)-1):\n            if (first_trade_buy == True and idx % 2 == 0) or (first_trade_buy == False and idx % 2 == 1):\n                # normal\n                earning = 100 * ((price[idx+1] / price[idx]) * 0.99925 * 0.99925 - 1)\n                buy_sell_log.append(earning)\n            else:\n                # reverse\n                earning = 100 * ((price[idx] / price[idx+1]) * 0.99925 * 0.99925 - 1)\n                buy_sell_log.append(earning)\n\n\n\ndef get_perfomance(trade_log):\n    import numpy\n    win = []\n    lose = []\n    cdef int i = 0\n    cdef float win_Rate = 0.0\n    for i in range(len(trade_log)):\n        if trade_log[i] > 0:\n            win.append(trade_log[i])\n        elif trade_log[i] < 0:\n            lose.append(trade_log[i])\n    win_Rate = len(win) / len(trade_log)\n    print(\'평균손익비 :\', -1 * numpy.mean(win) / numpy.mean(lose))\n    print(\'승률 :\', win_Rate)\n    print(\'\')\n\n    return [win_Rate, -1 * numpy.mean(win) / numpy.mean(lose)]\n\n\ndef csv2list(filename):\n    file = open(filename, \'r\')\n    csvfile = csv.reader(file)\n    lists = []\n    for item in csvfile:\n        lists.append(item)\n    return lists\n\n\n\ncdef int i\ncdef int j\n\n\ncsv_ = csv2list(\'result.csv\')\nprice = []\nbuy_sell_log = []\n\nAll_ohlcv = []\n\nfor i in range(len(csv_)):\n    temp = [float(x) for x in csv_[i]]\n    All_ohlcv.append(temp)\n\n\n\'\'\'\nlog_maker(30, 2.5)\nget_perfomance(buy_sell_log)\nprice.clear()\nbuy_sell_log.clear()\n\n\n# a = [MA_value, STD_value, win_rate, avg_P&L, win_rate * (1 + avg_P&L) ]\n\n\'\'\'\ncsv_list = []\n\nfor i in range(2,4 ...
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2369             with self.builtin_trap:
#    2370                 args = (magic_arg_s, cell)
# -> 2371                 result = fn(*args, **kwargs)
#    2372             return result
#    2373
#
# <decorator-gen-129> in cython(self, line, cell)
#
# ~\anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\lib\site-packages\Cython\Build\IpythonMagic.py in cython(self, line, cell)
#     349             return None
#     350
# --> 351         module = imp.load_dynamic(module_name, module_path)
#     352         self._import_all(module)
#     353
#
# ~\anaconda3\lib\imp.py in load_dynamic(name, path, file)
#     340         spec = importlib.machinery.ModuleSpec(
#     341             name=name, loader=loader, origin=path)
# --> 342         return _load(spec)
#     343
#     344 else:
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _load(spec)
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _load_unlocked(spec)
#
# ~\anaconda3\lib\importlib\_bootstrap_external.py in exec_module(self, module)
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# _cython_magic_8ab92e3f1ad138e77034f0e5ea2ca537.pyx in init _cython_magic_8ab92e3f1ad138e77034f0e5ea2ca537()
#
# _cython_magic_8ab92e3f1ad138e77034f0e5ea2ca537.pyx in _cython_magic_8ab92e3f1ad138e77034f0e5ea2ca537.log_maker()
#
# _cython_magic_8ab92e3f1ad138e77034f0e5ea2ca537.pyx in _cython_magic_8ab92e3f1ad138e77034f0e5ea2ca537.bb()
#
# <__array_function__ internals> in std(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in std(a, axis, dtype, out, ddof, keepdims)
#    3456             return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
#    3457
# -> 3458     return _methods._std(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
#    3459                          **kwargs)
#    3460
#
# KeyboardInterrupt:
